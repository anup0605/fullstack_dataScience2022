# %%
from flask import Flask,render_template,jsonify

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen as urReq

# %%
flipkart_url='https://www.flipkart.com/search?q='+'iPhone11'

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iPhone11'

# %%
website_response=urReq(flipkart_url)

# %%
data_flipkart=website_response.read()

# %%
bs_html=bs(data_flipkart,"html.parser")

# %%
bs_html.find_all("div",{"class":"_1AtVbE col-12-12"})
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iPhone11&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy
# ...

# %%
len(bs_html.find_all("div",{"class":"_1AtVbE col-12-12"}))
# Out:
# 29

# %%
bigbox=bs_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
bigbox[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iPhone11&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,
# ...

# %%
bigbox[5].div.div.div.a["href"]
# Out:
# '/apple-iphone-11-black-64-gb/p/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART&q=iPhone11&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=87a209e0-9ac8-4571-9302-fe0ffe6b4e13.MOBFWQ6BXGJCEYNY.SEARCH&ppt=None&ppn=None&ssid=rszuggz3xs0000001661853078477&qH=9528e179659b7992'

# %%
product4=flipkart_url+bigbox[4].div.div.div.a["href"]

# %%
product5='https://www.flipkart.com' + bigbox[5].div.div.div.a["href"]
# 'https://www.flipkart.com' + bigbox[5].div.div.div.a["href"]

# %%
import requests

# %%
product55=requests.get(product5)

# %%
product55.encoding='utf-8'

# %%
product5_page=bs(product55.text,"html.parser")

# %%
product5
# Out:
# 'https://www.flipkart.com/apple-iphone-11-black-64-gb/p/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART&q=iPhone11&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=87a209e0-9ac8-4571-9302-fe0ffe6b4e13.MOBFWQ6BXGJCEYNY.SEARCH&ppt=None&ppn=None&ssid=rszuggz3xs0000001661853078477&qH=9528e179659b7992'

# %%
all_review=product5_page.find_all("div",{"class":"_16PBlm"})

# %%
all_review
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Simply awesome</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202011/blobio-imr-202011_e4b34b9e355e4836ade8b1f6345ee73b.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Flipkart Customer</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path 
# ...

# %%
len(all_review)
# Out:
# 11

# %%
all_review[0].div.div.div.div.text
# Out:
# '5'

# %%
all_review[0].div.div.div.find_all('p',{"class":"_2-N8zT"})[0].text
# Out:
# 'Simply awesome'

# %%
all_review[0].div.div.find_all("div",{"class":"t-ZTKy"})[0].div.div.text
# Out:
# 'Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.'

# %%
find_name=all_review[0].div.div.find_all("div",{"class":"row _3n8db9"})[0].div.p

# %%
find_name.text
# Out:
# 'Flipkart Customer'
